# %%
import pandas as pd
import matplotlib.pyplot as plt
import hydropandas as hpd

hpd.util.get_color_logger("INFO")
# Out:
# <RootLogger root (INFO)>

# %%
organisation = "rotterdam"

auth = ("__key__", "D5aclEis.RBUeIvKA6jrLVUzNpPATjvGyLXsLAx7P")

# %% [markdown]
# **Het extent is in Rijksdriehoek (xmin, xmax, ymin, ymax). Meetpunten binnen dit extent worden ingeladen.**
#
# **Met which-timeseries kun je de bron van de grondwatermetingen selecteren:**
# - Hand is handmatig gemeten door een persoon
# - Diver is gemeten met een sensor
# - Diver_validated is gemeten met een sensor en gevalideerd door de databeheerder

# %%
my_extent = (89945, 91552, 440688, 441553) 
oc = hpd.read_lizard(
    extent=my_extent,
    which_timeseries=["hand", "diver", "diver_validated"],
    datafilters=None,
    combine_method="merge",
    organisation=organisation,
    auth=auth,
)
# Out:
# INFO:hydropandas.io.lizard.get_obs_list_from_extent:Number of monitoring wells: 10
# INFO:hydropandas.io.lizard.get_obs_list_from_extent:Number of pages: 1
# Page: 100%|██████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.96it/s]
# monitoring well: 100%|█████████████████████████████████████████████████████████████████| 10/10 [00:03<00:00,  3.15it/s]

# %%
oc
# Out:
#                                x              y    location filename  source  \
# name
# GMW000000036741001  90998.687871  441239.318459   MEIJPL-12           lizard
# GMW000000036965001  91525.037726  441090.628347  128572-792           lizard
# GMW000000036989001  90664.868686  441145.728338    127572-1           lizard
# GMW000000037445001  90407.518334  440789.329306    127571-4           lizard
# GMW000000038220001  91303.067938  441217.968233  128572-795           lizard
# GMW000000098093001  91547.087277  441459.765282  128572-798           lizard
# GMW000000101405001  91513.987745  441096.026782    128572-9           lizard
# GMW000000101406001  91466.987589  441235.026233   128572-12           lizard
# GMW000000101454001  91522.988168  440812.027927    128571-3           lizard
# GMW000000102198001  91500.987260  441452.025291   128572-14           lizard
#
#                      unit  tube_nr  screen_top  screen_bottom  ground_level  \
# name
# GMW000000036741001  m NAP        1     -15.680        -16.680        -4.560
# GMW000000036965001  m NAP        1      -5.970         -6.970        -4.850
# GMW000000036989001  m NAP        1      -5.150         -7.150        -4.340
# GMW000000037445001  m NAP        1      -5.390         -7.390        -4.830
# GMW000000038220001  m NAP        1     -16.560        -18.560        -4.680
# GMW000000098093001  m NAP        1      -6.807         -7.807        -4.807
# GMW000000101405001  m NAP        1      -6.410         -7.410        -4.860
# GMW000000101406001  m NAP        1      -6.390         -7.390        -4.840
# GMW000000101454001  m NAP        1      -6.390         -7.390        -4.740
# GMW000000102198001  m NAP        1      -6.180         -7.180        -4.620
#
#                     tube_top  metadata_available  \
# name
# GMW000000036741001    -2.680                True
# GMW000000036965001    -4.970                True
# GMW000000036989001    -4.350                True
# GMW000000037445001    -4.890                True
# GMW000000038220001    -3.560                True
# GMW000000098093001    -4.884                True
# GMW000000101405001    -4.860                True
# GMW000000101406001    -4.840                True
# GMW000000101454001    -4.740                True
# GMW000000102198001    -4.620                True
#
#                                                                   obs
# name
# GMW000000036741001  GroundwaterObs GMW000000036741001
# -----metadat...
# GMW000000036965001  GroundwaterObs GMW000000036965001
# -----metadat...
# GMW000000036989001  GroundwaterObs GMW000000036989001
# -----metadat...
# GMW000000037445001  GroundwaterObs GMW000000037445001
# -----metadat...
# GMW000000038220001  GroundwaterObs GMW000000038220001
# -----metadat...
# GMW000000098093001  GroundwaterObs GMW000000098093001
# -----metadat...
# GMW000000101405001  GroundwaterObs GMW000000101405001
# -----metadat...
# GMW000000101406001  GroundwaterObs GMW000000101406001
# -----metadat...
# GMW000000101454001  GroundwaterObs GMW000000101454001
# -----metadat...
# GMW000000102198001  GroundwaterObs GMW000000102198001
# -----metadat...

# %% [markdown]
# **In deze stap wordt één specifieke peilbuis geselecteerd uit de ObsCollection op basis van de unieke well code.**

# %%
gw = oc.obs["GMW000000036741001"]
print(gw)
# Out:
# GroundwaterObs GMW000000036741001
# -----metadata------
# name : GMW000000036741001
# x : 90998.68787131566
# y : 441239.3184593285
# location : MEIJPL-12
# filename :
# source : lizard
# unit : m NAP
# tube_nr : 1
# screen_top : -15.68
# screen_bottom : -16.68
# ground_level : -4.56
# tube_top : -2.68
# metadata_available : True
#
# -----time series------
#                      value  flag        comment origin
# peil_datum_tijd
# 2007-09-13 23:00:00  -4.03   NaN        Gemeten   hand
# 2007-09-18 23:00:00  -4.35   NaN        Gemeten   hand
# 2019-11-13 08:00:00    NaN   NaN  niet te meten   hand
# 2019-11-28 13:30:00    NaN   NaN  niet te meten   hand
# 2020-01-10 13:29:00    NaN   NaN  niet te meten   hand
# ...                    ...   ...            ...    ...
# 2025-08-04 12:03:33  -4.18   2.0        Gemeten   hand
# 2025-09-04 09:18:08  -4.19   2.0        Gemeten   hand
# 2025-10-01 12:21:49  -4.21   2.0        Gemeten   hand
# 2025-11-06 15:02:13  -4.07   2.0        Gemeten   hand
# 2025-12-10 08:05:58  -4.09   2.0        Gemeten   hand
#
# [70 rows x 4 columns]

# %% [markdown]
# **In deze stap wordt de grondwaterstandtijdreeks uit de geselecteerde peilbuis geëxtraheerd en opgeschoond:**
#
# - De kolom "value" (grondwaterstand) wordt gekopieerd uit het "GroundwaterObs" object
# - De datums worden omgezet naar pandas datetimes zodat tijdreeks bewerkingen mogelijk zijn
# - Ontbrekende metingen (NaN-waarden) worden verwijderd
#
# **Tot slot wordt gecontroleerd:**
# - Wat de eerste en laatste meetdatum zijn
# - Hoeveel metingen de tijdreeks bevat

# %%
ts = gw["value"].copy()
ts.index = pd.to_datetime(ts.index)
ts = ts.dropna()

print(ts.index.min(), ts.index.max())
print(ts.shape)
# Out:
# 2007-09-13 23:00:00 2025-12-10 08:05:58
# (67,)

# %% [markdown]
# **In deze stap wordt de tijdreeks beperkt tot de gekozen analyseperiode. Vervolgens wordt in het geval van meerdere metingen per dag een gemiddelde genomen zodat de tijdreeks maximaal 1 waarde per dag bevat en geschikt is om te plotten.**

# %%
ts_year = ts.loc["2024-11-01":"2025-10-31"]

# Dagelijkse reeks
ts_daily_raw = ts_year.resample("D").mean()

# Interpolatie (volledig automatisch)
ts_daily = ts_daily_raw.interpolate(method="time")

# Bijhouden welke dagen GEÏNTERPOLEERD zijn
is_interpolated = ts_daily_raw.isna()

# %% [markdown]
# **In deze stap wordt een vaste droogtedrempel bepaald op basis van een percentiel van de volledige grondwaterstandtijdreeks.**
#
# **Het 30e percentiel betekent dat 30% van alle gemeten grondwaterstanden lager ligt dan deze waarde. Deze drempel wordt gebruikt om droogte te identificeren: wanneer de grondwaterstand onder deze waarde komt, wordt dit als een droogteconditie beschouwd.**

# %%
# Percentiel instellen
percentile = 0.30
threshold = ts_year.quantile(percentile)

# Bouw percentiel-uitleg tabel op RUWE DATA
df_pct = (
    ts_year          # ← NU gefilterd
    .sort_values()
    .to_frame(name="value")
    .reset_index(names="date")
)


df_pct["rank"] = range(1, len(df_pct) + 1)
df_pct["cum_frac"] = df_pct["rank"] / len(df_pct)
df_pct["below_threshold"] = df_pct["value"] <= threshold
df_pct["is_percentile_boundary"] = (
    (df_pct["cum_frac"] >= percentile) &
    (df_pct["cum_frac"].shift(1) < percentile)
)

print(f"Fixed threshold (30th percentile): {threshold:.2f} m NAP")

df_pct
# Out:
# Fixed threshold (30th percentile): -4.21 m NAP
#                   date  value  rank  cum_frac  below_threshold  \
# 0  2025-03-05 10:32:00  -4.74     1  0.083333             True
# 1  2025-02-10 10:11:00  -4.72     2  0.166667             True
# 2  2025-03-31 09:08:00  -4.68     3  0.250000             True
# 3  2025-10-01 12:21:49  -4.21     4  0.333333             True
# 4  2025-06-02 10:57:00  -4.20     5  0.416667            False
# 5  2025-06-30 13:59:51  -4.20     6  0.500000            False
# 6  2025-05-08 05:16:00  -4.19     7  0.583333            False
# 7  2025-09-04 09:18:08  -4.19     8  0.666667            False
# 8  2025-08-04 12:03:33  -4.18     9  0.750000            False
# 9  2024-11-15 11:50:00  -4.14    10  0.833333            False
# 10 2025-01-09 09:48:00  -4.14    11  0.916667            False
# 11 2024-12-03 11:35:00  -4.08    12  1.000000            False
#
#     is_percentile_boundary
# 0                    False
# 1                    False
# 2                    False
# 3                     True
# 4                    False
# 5                    False
# 6                    False
# 7                    False
# 8                    False
# 9                    False
# 10                   False
# 11                   False

# %%
is_drought = ts_daily < threshold

# %% [markdown]
# **In deze stap wordt per dag bepaald of er sprake is van eengrondwaterdroogte.**
#
# **Een dag wordt als droogtedag geclassificeerd wanneer de dagelijkse
# grondwaterstand lager is dan de vastgestelde droogtedrempel.**

# %%
fig, ax = plt.subplots(figsize=(10, 4))

# Groundwater level
ax.plot(
    ts_daily.index,
    ts_daily,
    color="steelblue",
    linewidth=1.5,
    label="daily groundwater level",
)

# Fixed threshold
ax.axhline(threshold, color="orange", linewidth=2, label="threshold")

ax.fill_between(
    ts_daily.index,
    ts_daily,
    threshold,
    where=is_drought,
    color="red",
    alpha=0.5,
    label="drought event",
    interpolate=True,
)

ax.set_ylabel("Groundwater level (m NAP)")
ax.set_xlabel("Date")
ax.set_title(f"Groundwater drought – {gw.name}")
ax.legend()

plt.tight_layout()
plt.show()

# %%
duration_days = is_drought.sum()
max_deficit = (threshold - ts_daily[is_drought]).max()

n_interpolated = is_interpolated.sum()

print(
    f"Drought duration (2024–2025): {duration_days} days. "
    f"{n_interpolated} days were interpolated."
)
print(f"Maximum deficit (2024–2025): {max_deficit:.2f} m")
# Out:
# Drought duration (2024–2025): 119 days. 309 days were interpolated.
# Maximum deficit (2024–2025): 0.53 m

# %%
# Origin per dag
origin_per_day = (
    gw[["value", "origin"]]
    .dropna()
    .assign(date=lambda df: df.index.normalize())
    .groupby("date")["origin"]
    .agg(lambda x: ",".join(sorted(set(x))))
)

summary = pd.DataFrame({
    "value": ts_daily,
    "interpolated": is_interpolated
})

summary["origin"] = origin_per_day
summary.loc[summary["interpolated"], "origin"] = "interpolated"

pd.set_option("display.max_rows", None)
summary
# Out:
#                     value  interpolated        origin
# peil_datum_tijd
# 2024-11-15      -4.140000         False          hand
# 2024-11-16      -4.136667          True  interpolated
# 2024-11-17      -4.133333          True  interpolated
# 2024-11-18      -4.130000          True  interpolated
# 2024-11-19      -4.126667          True  interpolated
# 2024-11-20      -4.123333          True  interpolated
# 2024-11-21      -4.120000          True  interpolated
# 2024-11-22      -4.116667          True  interpolated
# 2024-11-23      -4.113333          True  interpolated
# 2024-11-24      -4.110000          True  interpolated
# 2024-11-25      -4.106667          True  interpolated
# 2024-11-26      -4.103333          True  interpolated
# 2024-11-27      -4.100000          True  interpolated
# 2024-11-28      -4.096667          True  interpolated
# 2024-11-29      -4.093333          True  interpolated
# 2024-11-30      -4.090000          True  interpolated
# 2024-12-01      -4.086667          True  interpolated
# 2024-12-02      -4.083333          True  interpolated
# 2024-12-03      -4.080000         False          hand
# 2024-12-04      -4.081622          True  interpolated
# 2024-12-05      -4.083243          True  interpolated
# 2024-12-06      -4.084865          True  interpolated
# 2024-12-07      -4.086486          True  interpolated
# 2024-12-08      -4.088108          True  interpolated
# 2024-12-09      -4.089730          True  interpolated
# 2024-12-10      -4.091351          True  interpolated
# 2024-12-11      -4.092973          True  interpolated
# 2024-12-12      -4.094595          True  interpolated
# 2024-12-13      -4.096216          True  interpolated
# 2024-12-14      -4.097838          True  interpolated
# 2024-12-15      -4.099459          True  interpolated
# 2024-12-16      -4.101081          True  interpolated
# 2024-12-17      -4.102703          True  interpolated
# 2024-12-18      -4.104324          True  interpolated
# 2024-12-19      -4.105946          True  interpolated
# 2024-12-20      -4.107568          True  interpolated
# 2024-12-21      -4.109189          True  interpolated
# 2024-12-22      -4.110811          True  interpolated
# 2024-12-23      -4.112432          True  interpolated
# 2024-12-24      -4.114054          True  interpolated
# 2024-12-25      -4.115676          True  interpolated
# 2024-12-26      -4.117297          True  interpolated
# 2024-12-27      -4.118919          True  interpolated
# 2024-12-28      -4.120541          True  interpolated
# 2024-12-29      -4.122162          True  interpolated
# 2024-12-30      -4.123784          True  interpolated
# 2024-12-31      -4.125405          True  interpolated
# 2025-01-01      -4.127027          True  interpolated
# 2025-01-02      -4.128649          True  interpolated
# 2025-01-03      -4.130270          True  interpolated
# 2025-01-04      -4.131892          True  interpolated
# 2025-01-05      -4.133514          True  interpolated
# 2025-01-06      -4.135135          True  interpolated
# 2025-01-07      -4.136757          True  interpolated
# 2025-01-08      -4.138378          True  interpolated
# 2025-01-09      -4.140000         False          hand
# 2025-01-10      -4.158125          True  interpolated
# 2025-01-11      -4.176250          True  interpolated
# 2025-01-12      -4.194375          True  interpolated
# 2025-01-13      -4.212500          True  interpolated
# 2025-01-14      -4.230625          True  interpolated
# 2025-01-15      -4.248750          True  interpolated
# 2025-01-16      -4.266875          True  interpolated
# 2025-01-17      -4.285000          True  interpolated
# 2025-01-18      -4.303125          True  interpolated
# 2025-01-19      -4.321250          True  interpolated
# 2025-01-20      -4.339375          True  interpolated
# 2025-01-21      -4.357500          True  interpolated
# 2025-01-22      -4.375625          True  interpolated
# 2025-01-23      -4.393750          True  interpolated
# 2025-01-24      -4.411875          True  interpolated
# 2025-01-25      -4.430000          True  interpolated
# 2025-01-26      -4.448125          True  interpolated
# 2025-01-27      -4.466250          True  interpolated
# 2025-01-28      -4.484375          True  interpolated
# 2025-01-29      -4.502500          True  interpolated
# 2025-01-30      -4.520625          True  interpolated
# 2025-01-31      -4.538750          True  interpolated
# 2025-02-01      -4.556875          True  interpolated
# 2025-02-02      -4.575000          True  interpolated
# 2025-02-03      -4.593125          True  interpolated
# 2025-02-04      -4.611250          True  interpolated
# 2025-02-05      -4.629375          True  interpolated
# 2025-02-06      -4.647500          True  interpolated
# 2025-02-07      -4.665625          True  interpolated
# 2025-02-08      -4.683750          True  interpolated
# 2025-02-09      -4.701875          True  interpolated
# 2025-02-10      -4.720000         False          hand
# 2025-02-11      -4.720870          True  interpolated
# 2025-02-12      -4.721739          True  interpolated
# 2025-02-13      -4.722609          True  interpolated
# 2025-02-14      -4.723478          True  interpolated
# 2025-02-15      -4.724348          True  interpolated
# 2025-02-16      -4.725217          True  interpolated
# 2025-02-17      -4.726087          True  interpolated
# 2025-02-18      -4.726957          True  interpolated
# 2025-02-19      -4.727826          True  interpolated
# 2025-02-20      -4.728696          True  interpolated
# 2025-02-21      -4.729565          True  interpolated
# 2025-02-22      -4.730435          True  interpolated
# 2025-02-23      -4.731304          True  interpolated
# 2025-02-24      -4.732174          True  interpolated
# 2025-02-25      -4.733043          True  interpolated
# 2025-02-26      -4.733913          True  interpolated
# 2025-02-27      -4.734783          True  interpolated
# 2025-02-28      -4.735652          True  interpolated
# 2025-03-01      -4.736522          True  interpolated
# 2025-03-02      -4.737391          True  interpolated
# 2025-03-03      -4.738261          True  interpolated
# 2025-03-04      -4.739130          True  interpolated
# 2025-03-05      -4.740000         False          hand
# 2025-03-06      -4.737692          True  interpolated
# 2025-03-07      -4.735385          True  interpolated
# 2025-03-08      -4.733077          True  interpolated
# 2025-03-09      -4.730769          True  interpolated
# 2025-03-10      -4.728462          True  interpolated
# 2025-03-11      -4.726154          True  interpolated
# 2025-03-12      -4.723846          True  interpolated
# 2025-03-13      -4.721538          True  interpolated
# 2025-03-14      -4.719231          True  interpolated
# 2025-03-15      -4.716923          True  interpolated
# 2025-03-16      -4.714615          True  interpolated
# 2025-03-17      -4.712308          True  interpolated
# 2025-03-18      -4.710000          True  interpolated
# 2025-03-19      -4.707692          True  interpolated
# 2025-03-20      -4.705385          True  interpolated
# 2025-03-21      -4.703077          True  interpolated
# 2025-03-22      -4.700769          True  interpolated
# 2025-03-23      -4.698462          True  interpolated
# 2025-03-24      -4.696154          True  interpolated
# 2025-03-25      -4.693846          True  interpolated
# 2025-03-26      -4.691538          True  interpolated
# 2025-03-27      -4.689231          True  interpolated
# 2025-03-28      -4.686923          True  interpolated
# 2025-03-29      -4.684615          True  interpolated
# 2025-03-30      -4.682308          True  interpolated
# 2025-03-31      -4.680000         False          hand
# 2025-04-01      -4.667105          True  interpolated
# 2025-04-02      -4.654211          True  interpolated
# 2025-04-03      -4.641316          True  interpolated
# 2025-04-04      -4.628421          True  interpolated
# 2025-04-05      -4.615526          True  interpolated
# 2025-04-06      -4.602632          True  interpolated
# 2025-04-07      -4.589737          True  interpolated
# 2025-04-08      -4.576842          True  interpolated
# 2025-04-09      -4.563947          True  interpolated
# 2025-04-10      -4.551053          True  interpolated
# 2025-04-11      -4.538158          True  interpolated
# 2025-04-12      -4.525263          True  interpolated
# 2025-04-13      -4.512368          True  interpolated
# 2025-04-14      -4.499474          True  interpolated
# 2025-04-15      -4.486579          True  interpolated
# 2025-04-16      -4.473684          True  interpolated
# 2025-04-17      -4.460789          True  interpolated
# 2025-04-18      -4.447895          True  interpolated
# 2025-04-19      -4.435000          True  interpolated
# 2025-04-20      -4.422105          True  interpolated
# 2025-04-21      -4.409211          True  interpolated
# 2025-04-22      -4.396316          True  interpolated
# 2025-04-23      -4.383421          True  interpolated
# 2025-04-24      -4.370526          True  interpolated
# 2025-04-25      -4.357632          True  interpolated
# 2025-04-26      -4.344737          True  interpolated
# 2025-04-27      -4.331842          True  interpolated
# 2025-04-28      -4.318947          True  interpolated
# 2025-04-29      -4.306053          True  interpolated
# 2025-04-30      -4.293158          True  interpolated
# 2025-05-01      -4.280263          True  interpolated
# 2025-05-02      -4.267368          True  interpolated
# 2025-05-03      -4.254474          True  interpolated
# 2025-05-04      -4.241579          True  interpolated
# 2025-05-05      -4.228684          True  interpolated
# 2025-05-06      -4.215789          True  interpolated
# 2025-05-07      -4.202895          True  interpolated
# 2025-05-08      -4.190000         False          hand
# 2025-05-09      -4.190400          True  interpolated
# 2025-05-10      -4.190800          True  interpolated
# 2025-05-11      -4.191200          True  interpolated
# 2025-05-12      -4.191600          True  interpolated
# 2025-05-13      -4.192000          True  interpolated
# 2025-05-14      -4.192400          True  interpolated
# 2025-05-15      -4.192800          True  interpolated
# 2025-05-16      -4.193200          True  interpolated
# 2025-05-17      -4.193600          True  interpolated
# 2025-05-18      -4.194000          True  interpolated
# 2025-05-19      -4.194400          True  interpolated
# 2025-05-20      -4.194800          True  interpolated
# 2025-05-21      -4.195200          True  interpolated
# 2025-05-22      -4.195600          True  interpolated
# 2025-05-23      -4.196000          True  interpolated
# 2025-05-24      -4.196400          True  interpolated
# 2025-05-25      -4.196800          True  interpolated
# 2025-05-26      -4.197200          True  interpolated
# 2025-05-27      -4.197600          True  interpolated
# 2025-05-28      -4.198000          True  interpolated
# 2025-05-29      -4.198400          True  interpolated
# 2025-05-30      -4.198800          True  interpolated
# 2025-05-31      -4.199200          True  interpolated
# 2025-06-01      -4.199600          True  interpolated
# 2025-06-02      -4.200000         False          hand
# 2025-06-03      -4.200000          True  interpolated
# 2025-06-04      -4.200000          True  interpolated
# 2025-06-05      -4.200000          True  interpolated
# 2025-06-06      -4.200000          True  interpolated
# 2025-06-07      -4.200000          True  interpolated
# 2025-06-08      -4.200000          True  interpolated
# 2025-06-09      -4.200000          True  interpolated
# 2025-06-10      -4.200000          True  interpolated
# 2025-06-11      -4.200000          True  interpolated
# 2025-06-12      -4.200000          True  interpolated
# 2025-06-13      -4.200000          True  interpolated
# 2025-06-14      -4.200000          True  interpolated
# 2025-06-15      -4.200000          True  interpolated
# 2025-06-16      -4.200000          True  interpolated
# 2025-06-17      -4.200000          True  interpolated
# 2025-06-18      -4.200000          True  interpolated
# 2025-06-19      -4.200000          True  interpolated
# 2025-06-20      -4.200000          True  interpolated
# 2025-06-21      -4.200000          True  interpolated
# 2025-06-22      -4.200000          True  interpolated
# 2025-06-23      -4.200000          True  interpolated
# 2025-06-24      -4.200000          True  interpolated
# 2025-06-25      -4.200000          True  interpolated
# 2025-06-26      -4.200000          True  interpolated
# 2025-06-27      -4.200000          True  interpolated
# 2025-06-28      -4.200000          True  interpolated
# 2025-06-29      -4.200000          True  interpolated
# 2025-06-30      -4.200000         False          hand
# 2025-07-01      -4.199429          True  interpolated
# 2025-07-02      -4.198857          True  interpolated
# 2025-07-03      -4.198286          True  interpolated
# 2025-07-04      -4.197714          True  interpolated
# 2025-07-05      -4.197143          True  interpolated
# 2025-07-06      -4.196571          True  interpolated
# 2025-07-07      -4.196000          True  interpolated
# 2025-07-08      -4.195429          True  interpolated
# 2025-07-09      -4.194857          True  interpolated
# 2025-07-10      -4.194286          True  interpolated
# 2025-07-11      -4.193714          True  interpolated
# 2025-07-12      -4.193143          True  interpolated
# 2025-07-13      -4.192571          True  interpolated
# 2025-07-14      -4.192000          True  interpolated
# 2025-07-15      -4.191429          True  interpolated
# 2025-07-16      -4.190857          True  interpolated
# 2025-07-17      -4.190286          True  interpolated
# 2025-07-18      -4.189714          True  interpolated
# 2025-07-19      -4.189143          True  interpolated
# 2025-07-20      -4.188571          True  interpolated
# 2025-07-21      -4.188000          True  interpolated
# 2025-07-22      -4.187429          True  interpolated
# 2025-07-23      -4.186857          True  interpolated
# 2025-07-24      -4.186286          True  interpolated
# 2025-07-25      -4.185714          True  interpolated
# 2025-07-26      -4.185143          True  interpolated
# 2025-07-27      -4.184571          True  interpolated
# 2025-07-28      -4.184000          True  interpolated
# 2025-07-29      -4.183429          True  interpolated
# 2025-07-30      -4.182857          True  interpolated
# 2025-07-31      -4.182286          True  interpolated
# 2025-08-01      -4.181714          True  interpolated
# 2025-08-02      -4.181143          True  interpolated
# 2025-08-03      -4.180571          True  interpolated
# 2025-08-04      -4.180000         False          hand
# 2025-08-05      -4.180323          True  interpolated
# 2025-08-06      -4.180645          True  interpolated
# 2025-08-07      -4.180968          True  interpolated
# 2025-08-08      -4.181290          True  interpolated
# 2025-08-09      -4.181613          True  interpolated
# 2025-08-10      -4.181935          True  interpolated
# 2025-08-11      -4.182258          True  interpolated
# 2025-08-12      -4.182581          True  interpolated
# 2025-08-13      -4.182903          True  interpolated
# 2025-08-14      -4.183226          True  interpolated
# 2025-08-15      -4.183548          True  interpolated
# 2025-08-16      -4.183871          True  interpolated
# 2025-08-17      -4.184194          True  interpolated
# 2025-08-18      -4.184516          True  interpolated
# 2025-08-19      -4.184839          True  interpolated
# 2025-08-20      -4.185161          True  interpolated
# 2025-08-21      -4.185484          True  interpolated
# 2025-08-22      -4.185806          True  interpolated
# 2025-08-23      -4.186129          True  interpolated
# 2025-08-24      -4.186452          True  interpolated
# 2025-08-25      -4.186774          True  interpolated
# 2025-08-26      -4.187097          True  interpolated
# 2025-08-27      -4.187419          True  interpolated
# 2025-08-28      -4.187742          True  interpolated
# 2025-08-29      -4.188065          True  interpolated
# 2025-08-30      -4.188387          True  interpolated
# 2025-08-31      -4.188710          True  interpolated
# 2025-09-01      -4.189032          True  interpolated
# 2025-09-02      -4.189355          True  interpolated
# 2025-09-03      -4.189677          True  interpolated
# 2025-09-04      -4.190000         False          hand
# 2025-09-05      -4.190741          True  interpolated
# 2025-09-06      -4.191481          True  interpolated
# 2025-09-07      -4.192222          True  interpolated
# 2025-09-08      -4.192963          True  interpolated
# 2025-09-09      -4.193704          True  interpolated
# 2025-09-10      -4.194444          True  interpolated
# 2025-09-11      -4.195185          True  interpolated
# 2025-09-12      -4.195926          True  interpolated
# 2025-09-13      -4.196667          True  interpolated
# 2025-09-14      -4.197407          True  interpolated
# 2025-09-15      -4.198148          True  interpolated
# 2025-09-16      -4.198889          True  interpolated
# 2025-09-17      -4.199630          True  interpolated
# 2025-09-18      -4.200370          True  interpolated
# 2025-09-19      -4.201111          True  interpolated
# 2025-09-20      -4.201852          True  interpolated
# 2025-09-21      -4.202593          True  interpolated
# 2025-09-22      -4.203333          True  interpolated
# 2025-09-23      -4.204074          True  interpolated
# 2025-09-24      -4.204815          True  interpolated
# 2025-09-25      -4.205556          True  interpolated
# 2025-09-26      -4.206296          True  interpolated
# 2025-09-27      -4.207037          True  interpolated
# 2025-09-28      -4.207778          True  interpolated
# 2025-09-29      -4.208519          True  interpolated
# 2025-09-30      -4.209259          True  interpolated
# 2025-10-01      -4.210000         False          hand
