# %%
import pastas as ps

import hydropandas as hpd

# %%
hpd.util.get_color_logger("INFO")
# Out:
# <RootLogger root (INFO)>

# %%
## Lizard uses the organisation parameter to specify the data source.
organisation = "vitens"  # or: "rotterdam"
auth = None

## UNCOMMENT AND SET YOUR API KEY IF YOU NEED TO SPECIFY CREDENTIALS
# your_api_key = "your_api_key_here"
# auth = ("__key__", your_api_key)

# %%
my_extent = (137_000, 138_000, 458_000, 459_000)
oc = hpd.read_lizard(
    extent=my_extent,
    which_timeseries=["hand", "diver", "diver_validated"],
    datafilters=None,
    combine_method="merge",
    organisation=organisation,
    auth=auth,
)
# Out:
# INFO:hydropandas.io.lizard.get_obs_list_from_extent:Number of monitoring wells: 1
# INFO:hydropandas.io.lizard.get_obs_list_from_extent:Number of pages: 1
# Page: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.78it/s]
# monitoring well: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.90s/it]

# %%
oc.plots.interactive_map(
    color="red", zoom_start=15, tiles="Esri.WorldImagery", popup_width=350
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95e252507a73e0db7115a163052b75fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95e252507a73e0db7115a163052b75fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95e252507a73e0db7115a163052b75fc = L.map(
#                 &quot;map_95e252507a73e0db7115a163052b75fc&quot;,
#                 {
#                     center: [52.117985266823, 5.130259670985705],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_228ee2dfc685b77d754f76c262be1bf2 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_228ee2dfc685b77d754f76c262be1bf2.addTo(map_95e252507a73e0db7115a163052b75fc);
#
#
#             var feature_group_37cbd266fd68c8acff277e08d3e90389 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_8fd2e16d81b808c06c8aa6868c95df8f = L.circleMarker(
#                 [52.117985266823, 5.130259670985705],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_37cbd266fd68c8acff277e08d3e90389);
#
#
#         var popup_c46f4bde067d1e421c4e75e8374be7cb = L.popup({
#   &quot;maxWidth&quot;: 350,
# });
#
#
#
#                 var i_frame_c078166fccd48e1be858b5879317e014 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;350&quot; style=&quot;border:none !important;&quot; height=&quot;233&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_c46f4bde067d1e421c4e75e8374be7cb.setContent(i_frame_c078166fccd48e1be858b5879317e014);
#
#
#
#         circle_marker_8fd2e16d81b808c06c8aa6868c95df8f.bindPopup(popup_c46f4bde067d1e421c4e75e8374be7cb)
#         ;
#
#
#
#
#             feature_group_37cbd266fd68c8acff277e08d3e90389.addTo(map_95e252507a73e0db7115a163052b75fc);
#
#
#             var layer_control_78d9eb12247368bf7607c49c8facb71a_layers = {
#                 base_layers : {
#                     &quot;esriworldimagery&quot; : tile_layer_228ee2dfc685b77d754f76c262be1bf2,
#                 },
#                 overlays :  {
#                     &quot;\u003cspan style=\\\&quot;color: red;\\\&quot;\u003e\u003c/span\u003e&quot; : feature_group_37cbd266fd68c8acff277e08d3e90389,
#                 },
#             };
#             let layer_control_78d9eb12247368bf7607c49c8facb71a = L.control.layers(
#                 layer_control_78d9eb12247368bf7607c49c8facb71a_layers.base_layers,
#                 layer_control_78d9eb12247368bf7607c49c8facb71a_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_95e252507a73e0db7115a163052b75fc);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oc
# Out:
#                        x              y  location filename  source   unit  \
# name
# UPWP016001  137401.64297  458893.683528  B31H0580           lizard  m NAP
# UPWP016003  137401.64297  458893.683528  B31H0580           lizard  m NAP
# UPWP016002  137401.64297  458893.683528  B31H0580           lizard  m NAP
#
#             tube_nr  screen_top  screen_bottom  ground_level  tube_top  \
# name
# UPWP016001        1      -22.43         -24.43          1.58     2.198
# UPWP016003        3      -65.43         -67.43          1.58     2.141
# UPWP016002        2      -53.93         -55.93          1.58     2.178
#
#             metadata_available  \
# name
# UPWP016001                True
# UPWP016003                True
# UPWP016002                True
#
#                                                           obs        lat  \
# name
# UPWP016001  GroundwaterObs UPWP016001
# -----metadata------
# ...  52.117985
# UPWP016003  GroundwaterObs UPWP016003
# -----metadata------
# ...  52.117985
# UPWP016002  GroundwaterObs UPWP016002
# -----metadata------
# ...  52.117985
#
#                 lon
# name
# UPWP016001  5.13026
# UPWP016003  5.13026
# UPWP016002  5.13026

# %%
oc.obs.values[0]
# Out:
# GroundwaterObs UPWP016001
# -----metadata------
# name : UPWP016001
# x : 137401.64297031244
# y : 458893.6835282785
# location : B31H0580
# filename :
# source : lizard
# unit : m NAP
# tube_nr : 1
# screen_top : -22.43
# screen_bottom : -24.43
# ground_level : 1.58
# tube_top : 2.198
# metadata_available : True
#
# -----time series------
#                      value  flag comment origin
# peil_datum_tijd
# 1976-04-15 12:00:00 -0.300     0           hand
# 1976-04-28 12:00:00 -0.260     0           hand
# 1976-05-18 12:00:00 -0.330     0           hand
# 1976-06-02 12:00:00 -0.230     0           hand
# 1976-06-17 12:00:00 -0.300     0           hand
# ...                    ...   ...     ...    ...
# 2025-09-25 00:00:00 -0.075     0          diver
# 2025-09-25 03:00:00 -0.075     0          diver
# 2025-09-25 06:00:00 -0.078     0          diver
# 2025-09-25 09:00:00 -0.073     0          diver
# 2025-09-25 09:50:01 -0.142     0           hand
#
# [34351 rows x 4 columns]

# %%
oc.plots.section_plot(plot_obs=True)
# Out:
# INFO:hydropandas.extensions.plots.section_plot:created sectionplot -> UPWP016001
# INFO:hydropandas.extensions.plots.section_plot:created sectionplot -> UPWP016003
# INFO:hydropandas.extensions.plots.section_plot:created sectionplot -> UPWP016002
# (<Figure size 1500x500 with 2 Axes>,
#  [<Axes: ylabel='m NAP'>, <Axes: ylabel='m NAP'>])

# %%
gw_lizard = hpd.GroundwaterObs.from_lizard(
    "UPWP016",
    tmin="1900-01-01",
    tmax="2030-01-01",
    organisation="vitens",
    auth=auth,
)
print(gw_lizard)

ax = gw_lizard["value"].plot(
    figsize=(12, 5),
    marker=".",
    grid=True,
    label=gw_lizard.name,
    legend=True,
    xlabel="Date",
    ylabel="m NAP",
    title="Groundwater observations for " + gw_lizard.name,
)
# Out:
# GroundwaterObs UPWP016001
# -----metadata------
# name : UPWP016001
# x : 137401.64297031244
# y : 458893.6835282785
# location : B31H0580
# filename :
# source : lizard
# unit : m NAP
# tube_nr : 1
# screen_top : -22.43
# screen_bottom : -24.43
# ground_level : 1.58
# tube_top : 2.198
# metadata_available : True
#
# -----time series------
#                      value  flag comment origin
# peil_datum_tijd
# 1976-04-15 12:00:00 -0.300     0           hand
# 1976-04-28 12:00:00 -0.260     0           hand
# 1976-05-18 12:00:00 -0.330     0           hand
# 1976-06-02 12:00:00 -0.230     0           hand
# 1976-06-17 12:00:00 -0.300     0           hand
# ...                    ...   ...     ...    ...
# 2025-09-25 00:00:00 -0.075     0          diver
# 2025-09-25 03:00:00 -0.075     0          diver
# 2025-09-25 06:00:00 -0.078     0          diver
# 2025-09-25 09:00:00 -0.073     0          diver
# 2025-09-25 09:50:01 -0.142     0           hand
#
# [34351 rows x 4 columns]

# %%
print(gw_lizard["flag"].value_counts(normalize=True) * 100)
gw_lizard[gw_lizard["flag"] == "onbetrouwbaar"]
# Out:
# flag
# 0    99.959244
# 1     0.017467
# 7     0.014556
# 6     0.005822
# 3     0.002911
# Name: proportion, dtype: float64
# GroundwaterObs UPWP016001
# -----metadata------
# name : UPWP016001
# x : 137401.64297031244
# y : 458893.6835282785
# location : B31H0580
# filename :
# source : lizard
# unit : m NAP
# tube_nr : 1
# screen_top : -22.43
# screen_bottom : -24.43
# ground_level : 1.58
# tube_top : 2.198
# metadata_available : True
#
# -----time series------
# Empty GroundwaterObs
# Columns: [value, flag, comment, origin]
# Index: []

# %%
# Get the precipitation and evaporation data from the KNMI
precipitation = hpd.PrecipitationObs.from_knmi(
    xy=(gw_lizard.x, gw_lizard.y),
    start=gw_lizard.index[0],
    end=gw_lizard.index[-1],
    fill_missing_obs=True,
)
evaporation = hpd.EvaporationObs.from_knmi(
    xy=(gw_lizard.x, gw_lizard.y),
    meteo_var="EV24",
    start=gw_lizard.index[0],
    end=gw_lizard.index[-1],
    fill_missing_obs=True,
)

# Create a Pastas Model
ml = ps.Model(
    gw_lizard.loc[gw_lizard["origin"] == "diver", "value"], name=gw_lizard.name
)

# Add the recharge data as explanatory variable
ts1 = ps.RechargeModel(
    precipitation["RH"].resample("D").first(),
    evaporation["EV24"].resample("D").first(),
    ps.Gamma(),
    name="rainevap",
    settings=("prec", "evap"),
)

# Add the stressmodel to the model and solve for period after 2015
ml.add_stressmodel(ts1)
ml.solve(tmin="2015")
ml.plots.results(figsize=(10, 6))
# Out:
# INFO:hydropandas.io.knmi.get_knmi_obs:get KNMI data from station nearest to coordinates (137401.64297031244, 458893.6835282785) and meteovariable RH
# INFO:hydropandas.io.knmi.fill_missing_measurements:knmi station De Bilt has no measurements for RH after 2025-09-25 01:00:00 and an end date of 2025-09-25 09:50:01 was requested. Changing end to 2025-09-25 01:00:00
# INFO:hydropandas.io.knmi._add_missing_indices:station 260 has no measurements after 2025-09-25 01:00:00
# INFO:hydropandas.io.knmi.get_knmi_obs:get KNMI data from station nearest to coordinates (137401.64297031244, 458893.6835282785) and meteovariable EV24
# INFO:hydropandas.io.knmi.fill_missing_measurements:knmi station De Bilt has no measurements for EV24 after 2025-09-25 01:00:00 and an end date of 2025-09-25 09:50:01 was requested. Changing end to 2025-09-25 01:00:00
# INFO:hydropandas.io.knmi._add_missing_indices:station 260 has no measurements after 2025-09-25 01:00:00
# WARNING:pastas.timeseries._validate_series:The Time Series 'value' has nan-values. Pastas will use the fill_nan settings to fill up the nan-values.
# INFO:pastas.timeseries._fill_nan:Time Series 'value': 9 nan-value(s) was/were found and filled with: drop.
# INFO:pastas.timeseries._fill_after:Time Series 'RH' was extended in the future to 2025-09-25 00:00:00 with the mean value (0.0024) of the time series.
# INFO:pastas.timeseries._fill_after:Time Series 'EV24' was extended in the future to 2025-09-25 00:00:00 with the mean value (0.0017) of the time series.
# WARNING:pastas.model._generate_warnings_report:Parameter 'rainevap_f' on upper bound: 0.00e+00
# Fit report UPWP016001                Fit Statistics
# ===================================================
# nfev     11                     EVP           60.50
# nobs     3921                   R2             0.61
# noise    False                  RMSE           0.03
# tmin     2015-01-01 00:00:00    AICc      -26608.67
# tmax     2025-09-25 09:00:00    BIC       -26577.32
# freq     D                      Obj            2.21
# freq_obs None                   ___
# warmup   3650 days 00:00:00     Interp.          No
# solver   LeastSquares           weights         Yes
#
# Parameters (5 optimized)
# ===================================================
#                  optimal     initial  vary
# rainevap_A  3.077607e+01  198.463375  True
# rainevap_n  9.259934e-01    1.000000  True
# rainevap_a  1.437934e+01   10.000000  True
# rainevap_f -3.755613e-14   -1.000000  True
# constant_d -2.061197e-01   -0.128291  True
#
# Warnings! (1)
# ===================================================
# Parameter 'rainevap_f' on upper bound: 0.00e+00
# [<Axes: xlabel='peil_datum_tijd', ylabel='Head'>,
#  <Axes: >,
#  <Axes: title={'right': "Stresses: ['RH', 'EV24']"}, ylabel='Rise'>,
#  <Axes: title={'center': 'Step response'}>,
#  <Axes: title={'left': 'Model parameters ($n_c$=5)'}>]
